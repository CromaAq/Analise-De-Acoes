# %% [markdown]
# <a href="https://colab.research.google.com/github/CromaAq/Analise-De-Acoes-Com-Python/blob/main/Analisando_A%C3%A7%C3%B5es_Empresas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando Bibliotecas

# %%
import numpy as np
import pandas as pd
import string
import warnings
warnings.filterwarnings('ignore')

import requests

# %% [markdown]
# # Obtendo e tratando os dados

# %%
url = 'http://www.fundamentus.com.br/resultado.php'

# %%
header = {
  "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"  
 }

r = requests.get(url, headers=header)

# %%
df = pd.read_html(r.text,  decimal=',', thousands='.')[0]

# %%
df
# Out:
#       Papel  Cotação      P/L  P/VP     PSR  Div.Yield  P/Ativo  P/Cap.Giro  \
# 10    RRRP3    44.40 -9939.37  2.19  12.359     0.0000    1.649        4.19
# 13    AALR3    18.95  -398.52  1.91   1.972     0.0000    0.882      -22.36
# 15    LWSA3     8.05  -301.70  1.62   5.938     0.0000    1.038        3.22
# 23    ELMD3    14.44  -176.09  2.63   4.863     0.0000    1.241        5.11
# 25    RCSL3     3.19  -147.94 -5.90   4.061     0.0000    3.653       54.15
# ..      ...      ...      ...   ...     ...        ...      ...         ...
# 977   BIDI3     5.41   402.90  1.64   0.000     0.0047    0.000        0.00
# 978  BIDI11    16.53   410.34  1.67   0.000     0.0046    0.000        0.00
# 979   BIDI4     5.64   420.02  1.71   0.000     0.0045    0.000        0.00
# 981   BRIT3     3.50   701.09  1.17   2.157     0.0000    0.543        2.24
# 982   TRAD3     4.16   975.56  1.91  12.791     0.0000    1.812        3.69
#
# ...

# %%
for coluna in ['Div.Yield', 'Mrg Ebit', 'Mrg. Líq.', 'ROIC', 'ROE', 'Cresc. Rec.5a']:
  df[coluna] = df[coluna].str.replace('.', '')
  df[coluna] = df[coluna].str.replace(',', '.')
  df[coluna] = df[coluna].str.rstrip('%').astype('float') / 100

# %% [markdown]
# # Analisando dados

# %%
df = df[df['Liq.2meses'] > 1000000]

# %%
ranking = pd.DataFrame()
ranking['pos'] = range(1,151)
ranking['EV/EBIT'] = df [ df['EV/EBIT'] > 0 ].sort_values(by=['EV/EBIT'])['Papel'][:150].values
ranking['ROIC'] = df.sort_values(by=['ROIC'], ascending=False)['Papel'][:150].values

# %%
ranking
# Out:
#      pos EV/EBIT    ROIC
# 0      1   PSSA3  BRBI11
# 1      2   INEP3   INEP3
# 2      3   GOAU4   CMIN3
# 3      4   SYNE3   PSSA3
# 4      5   USIM3   UNIP6
# ..   ...     ...     ...
# 145  146   HYPE3   AZUL4
# 146  147   RENT3   SEER3
# 147  148   BRIT3   TRIS3
# 148  149   COGN3   AMBP3
# 149  150   YDUQ3   CIEL3
#
# [150 rows x 3 columns]

# %%
a = ranking.pivot_table(columns='EV/EBIT', values='pos')

# %%
b = ranking.pivot_table(columns='ROIC', values='pos')

# %%
t = pd.concat([a,b])
t
# Out:
#      ABEV3  AGRO3  AGXY3  ALLD3  ALSO3  ALUP11  AMAR3  ASAI3  AURA33  AURE3  \
# pos    141     28     72     24  107.0      31     55     93      23  144.0
# pos     63     22    105     59    NaN      67    110     36       8    NaN
#
#      ...  PETZ3  RADL3  RDOR3  RECV3  RRRP3  TFCO4  TOTS3  VAMO3  VIVA3  WEGE3
# pos  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# pos  ...  136.0   97.0  125.0  142.0  135.0   32.0   60.0   83.0   68.0   34.0
#
# [2 rows x 173 columns]

# %%
rank = t.dropna(axis=1).sum()
rank
# Out:
# ABEV3     204
# AGRO3      50
# AGXY3     177
# ALLD3      83
# ALUP11     98
#          ...
# VITT3     176
# VLID3     224
# VULC3     203
# VVEO3     216
# WIZS3      59
# Length: 127, dtype: int64

# %%
rank.sort_values()[:15]
# Out:
# INEP3      4
# PSSA3      5
# SYNE3     17
# CMIN3     20
# BRKM5     22
# ETER3     23
# VALE3     25
# USIM5     25
# USIM3     25
# GOAU4     28
# FHER3     30
# PLPL3     30
# AURA33    31
# CSNA3     32
# MRFG3     33
# dtype: int64
